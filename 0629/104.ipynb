# %% [markdown]
# OK, so in this notebook, we're going to explore further these paradoxical features of Bell states. So remember that we said that if you measure the first qubit of the Bell state, you get $0\rangle$ and $|1\rangle$ with equal probability. But now, no matter how distant the second qubit is, instantaneously its state becomes equal to whatever you saw in the measurement of the first one. So if you saw $|0\rangle$, the state of the second qubit is $|0\rangle$. If you saw $|1\rangle$, the state of the second qubit is $|1\rangle$. So now let's repeat the same experiment, except we'll ask what happens if you measure the first qubit in the sign basis. Now remember what the sign basis is? We measure in the plus minus basis, where the plus state is
#
# $$|+\rangle = \frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle$$
#
# and the minus state is
#
# $$|-\rangle = \frac{1}{\sqrt{2}}|0\rangle - \frac{1}{\sqrt{2}}|1\rangle $$
#
# OK, so what are we interested in knowing? So we want to understand what's the probability we'll see a plus when we do the measurement.
# And then, if we saw plus, what's the probability that if we subsequently make a measurement of the second qubit that we also see plus? OK, so to answer these questions, it's actually useful to first change basis, and to write the Bell state in the plus minus basis. And the result of doing this is actually very nice, so you should try doing this (just for practice). And what you find is that the Bell state, when written in the plus minus basis,
# actually looks like ... the Bell state.
#
# So here's what I mean--that the Bell state in the plus minus basis is just an equal superposition of the state plus plus and the state minus minus:
#
# $$|\psi\rangle = \frac{1}{\sqrt{2}}|00\rangle + \frac{1}{\sqrt{2}}|11\rangle = \frac{1}{\sqrt{2}}|{+}{+}\rangle + \frac{1}{\sqrt{2}}|{-}{-}\rangle $$
#
# So let's see  why this is the case.
#
# $|\psi\rangle = \frac{1}{\sqrt{2}}|{+}{+}\rangle + \frac{1}{\sqrt{2}}|{-}{-}\rangle = \\
# ~~~~~~=\frac{1}{\sqrt{2}}\bigg[\bigg(\frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle\bigg) \bigg(\frac{1}{\sqrt{2}}|0\rangle + \frac{1}{\sqrt{2}}|1\rangle\bigg) + \bigg(\frac{1}{\sqrt{2}}|0\rangle - \frac{1}{\sqrt{2}}|1\rangle\bigg) \bigg(\frac{1}{\sqrt{2}}|0\rangle - \frac{1}{\sqrt{2}}|1\rangle\bigg) \bigg] = \\
# ~~~~~~= \frac{1}{\sqrt{2}}\bigg[\bigg(\frac{1}{2}|00\rangle + \frac{1}{2}|01\rangle + \frac{1}{2}|10\rangle + \frac{1}{2}|11\rangle\bigg) + \bigg(\frac{1}{2}|00\rangle - \frac{1}{2}|01\rangle - \frac{1}{2}|10\rangle + \frac{1}{2}|11\rangle\bigg)\bigg] = \\
# ~~~~~~=\frac{1}{\sqrt{2}}\Big(|00\rangle + |11\rangle\Big) = \frac{1}{\sqrt{2}}|00\rangle + \frac{1}{\sqrt{2}}|11\rangle$
#
# So these two are really equal. So now what does this tell us about the measurement question we looked at earlier? So what it says is, if you measure the first qubit, the probability that you see plus is exactly $\frac{1}{2}$ from the first term. And moreover, if you see plus, the new state is exactly plus plus, which means that if you now measure the second qubit, you see plus with probability $1$, right? If you make this measurement after you make the first one, you see (you always) see plus. And similarly, if you measure minus (with $P[-]=\frac{1}{2}$), then the new state is minus minus (and we write it $|{-}{-}\rangle$, and so the probability you see minus would be $1$. So in other words, if you want to know what the state of the second qubit is in the plus minus basis, you don't have to measure it. You can just measure the first qubit. OK, so this was the basis of the EPR Paradox, which was put forth as a thought experiment by Einstein, Podolsky, and Rosen.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So they said, well, suppose you want to know both the bit value and the sign value of this first qubit [we need to put an asterisk, like a rain check, here and we will come back to it towards the end]. So let's do this, then, let's entangle this qubit with another one, put them in this Bell state. And now, we're going to try to figure out both the bit and the sign value of this qubit in this state. And the way we will do this is we'll measure the bit on this first qubit. And the second qubit, we'll have moved to a distant planet or galaxy, so that they're space-like separated. And so, if you measure them almost at the same time in a space-like separated way, then clearly since light doesn't have time to get from the second qubit back to the first one, measuring the second qubit cannot disturb the first qubit. So now they said, suppose you measure the sign qubit. OK, so measure the sign qubit on the second qubit. Say you got the outcome plus, so now you know from what we said in the last slide that the sign of this first qubit is also plus. And so you know both the bit value, so let's say the bit value is a 0, and you know that the sign value is a plus, and this contradicts the uncertainty principle we just saw in the last lecture. [Here we need to cash the asterisk we promised earlier.] So here's the picture and I will explain in class what the point is:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# So now of course, when Einstein, Podolsky, and Rosen talked about the paradox, it was a little more complicated. They were talking about not qubits, but this was the content of what they were talking about. And so, what Einstein believed is that ... he had always had a problem with quantum mechanics, you must have heard the quote, "God does not pay dice with the universe." ... OK, so what Einstein believed is that quantum mechanics was an incomplete theory, that what it said was true, but it only provided partial information about what was going on in the physical system. And this was an attempt to show that you could, through tricky means, get at more information than quantum mechanics really wanted you to access from the physical system. And so, what Einstein believed is that there was a more complete theory, which he called a hidden variable theory, which would describe all of what was going on in this physical system, e.g., in the state of this electron. There's another way to see what the EPR paper put forth. They talked about local realism.
#
# So what is local realism? Locality is a very fundamental principle in physics.
# It goes back a long way, and how important it was to physicists you can deduce from understanding that Newton himself, when he came up with this theory of gravitation, he was very dissatisfied with it, because it seemed to posit that there were forces acting at a distance, that the Earth attracts the Moon. And the question was, what's the mechanism? And so it was very reluctantly much, much later that he published his theory. So to quote Isaac Newton himself, he says, "It is inconceivable that inanimate matter should, without the mediation of something else, which is not material, operate upon, and affect other matter without mutual contact." OK, so you can see this in the context of the theory of gravity.
#
# Now what is realism? Realism is this notion that a physical system exists in and of itself without our having to look at it. So Einstein talks about it. He says, "I think that matter must have a separate reality independent of the measurements. That is, an electron has spin, location, and so forth, even when it is not being measured. I like to think that the moon is there even if I'm not looking at it." So clearly, quantum mechanics is at odds with local realism, and Einstein spent the rest of his life trying to look for an alternate theory for a more complete theory that would admit to local realism. And he was looking for the so-called hidden variables theory. So now we can go back and ask, how would quantum mechanics really explain the EPR paradox?
#
# If you follow the rules of quantum mechanics, what do they say? If you haven't thought about this, you should spend a few minutes thinking about it. But here's what it would say: so, when you measure this first qubit in the bit basis, let's say you get the outcome $|0\rangle$. So now what's the new state. The new state is $|00\rangle$. This is not an entangled state anymore. You see, the measurement changed the state of the system, because you can write it as the first qubit is in the state 0, and the second qubit is in the state 0. So there's no entanglement between the two qubits. Now if you were to measure the sign of the second qubit, there's no entanglement. And so, if you measure the sign and it comes up plus, that has no bearing upon what the state of this first qubit is. It was already modified. It was already changed by the fact that we measured it.
#
# I'm sure you've realized that quantum mechanics is a bit slippery. Wrapping our minds around what quantum mechanics says is not always easy. And so in the next lecture, we'll talk about how you can understand these issues about entanglement at a much deeper level, and how they reveal something quite deep about quantum mechanics.
#
# ![image.png](data:image/png;base64,...)
